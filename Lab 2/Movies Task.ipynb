# %% [markdown]
# Name: Muhammad Mohsin Ahmad
#
# Roll No:010

# %% [markdown]
# TASK 2 MOVIES

# %%
movies = [
    ("Eternal Sunshine of the Spotless Mind", 20000000),
    ("Memento", 9000000),
    ("Requiem for a Dream", 4500000),
    ("Pirates of the Caribbean: On Stranger Tides", 379000000),
    ("Avengers: Age of Ultron", 365000000),
    ("Avengers: Endgame", 356000000),
    ("Incredibles 2", 200000000)
]

# %%
# Calculate total and then average budget of the movies
total_budget = 0
for movie in movies:
    total_budget += movie[1]  

average_budget = total_budget / len(movies)

print("\n")
print(f"Total Budget: ${total_budget}")
print("\n")
print(f"Average Budget: ${average_budget}")
# Out:
# Total Budget: $1333500000
#
#
# Average Budget: $190500000.0

# %%
# Print movies above average
above_average = []
for movie in movies:
    name = movie[0]
    budget = movie[1]
    if budget > average_budget:
        difference = budget - average_budget
        print(name, "had a budget $", round(difference), "higher than average.")
        above_average.append(name)

# Print how many movies exceeded the average budget
print("Number of movies above average:", len(above_average))
# Out:
# Pirates of the Caribbean: On Stranger Tides had a budget $ 188500000 higher than average.
# Avengers: Age of Ultron had a budget $ 174500000 higher than average.
# Avengers: Endgame had a budget $ 165500000 higher than average.
# Incredibles 2 had a budget $ 9500000 higher than average.
# Number of movies above average: 4
